# %%
import pandas as pd
import scrape_field
import urllib.request
from bs4 import BeautifulSoup
from collections import OrderedDict
import os
import run_stats

pagename = "http://www.pgatour.com/stats/stat."
pagenameend = "html"
ind_var = run_stats.stats

# %%
t_id='464'

# %%
run_stats.stats[stat]
# Out:
# 'SCRAM'

# %%
dk = pd.read_csv('dfs/draftkings.csv')
dk.set_index('Name', inplace=True)
for stat in ind_var.keys():
    page = pagename + str(stat) + '.' + pagenameend
    try:
        dk[stat] = pd.DataFrame.from_dict(run_stats.createdict(page), orient='index')
    except:
        print (run_stats.stats[stat], stat + ' No good')
        continue
dk.head()
# Out:
#                  Position                    Name + ID        ID  \
# Name
# Jon Rahm                G          Jon Rahm (19186909)  19186909
# Hideki Matsuyama        G  Hideki Matsuyama (19186910)  19186910
# Webb Simpson            G      Webb Simpson (19186911)  19186911
# Will Zalatoris          G    Will Zalatoris (19186912)  19186912
# Kevin Na                G          Kevin Na (19186913)  19186913
#
#                  Roster Position  Salary              Game Info TeamAbbrev  \
# Name
# Jon Rahm                       G   12100  Fortinet Championship       Golf
# Hideki Matsuyama               G   11000  Fortinet Championship       Golf
# Webb Simpson                   G   10800  Fortinet Championship       Golf
# Will Zalatoris                 G   10500  Fortinet Championship       Golf
# Kevin Na                       G   10000  Fortinet Championship       Golf
#
#                   AvgPointsPerGame    102    103  ...    327    328    329  \
# Name                                              ...
# Jon Rahm                     89.21  63.73  71.93  ...  60.34  67.42  73.14
# Hideki Matsuyama             71.11  62.25  67.03  ...  57.25  64.22  71.85
# Webb Simpson                 76.55  67.08  69.37  ...  65.26  67.29  74.59
# Will Zalatoris               81.70  56.40  69.54  ...  56.61  63.14  75.34
# Kevin Na                     68.96  66.56  64.11  ...  52.04  65.90  76.69
#
#                     330    352    399    459    460   461    467
# Name
# Jon Rahm          86.17  25.83  10.39  12.30  13.09  3.69  0.623
# Hideki Matsuyama  84.46  23.42   9.94  13.13  13.30  4.38  0.556
# Webb Simpson      87.01  24.85   9.73  14.10  10.58  4.35  0.536
# Will Zalatoris    84.48  22.22  10.51  13.80  18.90  4.67  0.528
# Kevin Na          82.84  22.73   9.40  12.28  12.19  3.05  0.433
#
# [5 rows x 44 columns]

# %%
df = pd.read_csv('table_data/tournament_plyr.csv', header=None)
df = df.loc[df[1] == int(t_id)]
df.head()
df.columns = ['p_id','t_id','tourn','year','id','5','6','name','8','place','score','11','lname','13']
df['MadeCut'] = 0
df.loc[df['score'] > 240, 'MadeCut'] = 1
df[list(ind_var.keys())] = None
year_dfs = {}
for year in df['year'].unique():
    if year > 2016:
        print(year)
        year_dfs[year]={}
        for stat in ind_var.keys():
            page = pagename + str(stat) + '.y' + str(year) + '.' + pagenameend
            try:
                year_dfs[year][stat] = run_stats.createdict(page)
            except:
                print (run_stats.stats[stat], str(stat) + ' No good')
                continue
# Out:
# PAR5 144 No good
# PUTT3 145 No good

# %%
for year in year_dfs.keys():
    for stat in year_dfs[year].keys():
        for name in year_dfs[year][stat].keys():
            df.loc[(df['year']==year)&(df['name']==name), stat] = year_dfs[year][stat][name]
